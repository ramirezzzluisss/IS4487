# %% [markdown]
# <a href="https://colab.research.google.com/github/ramirezzzluisss/IS4487/blob/main/Week9Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive 
drive.mount('/content/gdrive', force_remount=True)

df = pd.read_csv (r'/content/gdrive/MyDrive/Colab Notebooks/adviseinvest.csv')
# Out:
# Mounted at /content/gdrive

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29504 entries, 0 to 29503
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   answered        29504 non-null  int64
#  1   income          29504 non-null  int64
#  2   female          29504 non-null  int64
#  3   age             29504 non-null  int64
#  4   job             29504 non-null  int64
#  5   num_dependents  29504 non-null  int64
#  6   rent            29504 non-null  int64
#  7   own_res         29504 non-null  int64
#  8   new_car         29502 non-null  float64
#  9   chk_acct        29504 non-null  int64
#  10  sav_acct        29504 non-null  int64
#  11  num_accts       29504 non-null  int64
#  12  mobile          29504 non-null  int64
#  13  product         29504 non-null  int64
# dtypes: float64(1), int64(13)
# memory usage: 3.2 MB

# %%
df.head(5)
# Out:
#    answered  income  female  age  job  num_dependents  rent  own_res  new_car  \
# 0         1   13520       0   23    0               1     1        0      0.0
# 1         0   14780       0   22    2               1     0        1      0.0
# 2         1   37570       0   62    2               1     0        0      1.0
# 3         0   12450       0   33    2               1     0        1      0.0
# 4         0   12400       0   48    1               2     0        0      1.0
#
#    chk_acct  sav_acct  num_accts  mobile  product
# 0         0         2          0       1        2
# 1         3         0          3       0        0
# 2         3         0          4       0        4
# 3         1         0          2       0        0
# 4         2         1          4       0        0

# %%
df.describe()
# Out:
#            answered         income        female           age           job  \
# count  29504.000000   29504.000000  29504.000000  29504.000000  29504.000000
# mean       0.546638   33766.893303      0.054230     34.770065      1.915401
# std        0.497829   29379.202710      0.226475     11.355777      0.658183
# min        0.000000  -65600.000000      0.000000     19.000000      0.000000
# 25%        0.000000   13550.000000      0.000000     26.000000      2.000000
# 50%        1.000000   23310.000000      0.000000     32.000000      2.000000
# 75%        1.000000   41690.000000      0.000000     40.000000      2.000000
# max        1.000000  159450.000000      1.000000     74.000000      3.000000
#
#        num_dependents          rent       own_res       new_car      chk_acct  \
# count    29504.000000  29504.000000  29504.000000  29502.000000  29504.000000
# mean         1.140998      0.210412      0.681128      0.240797      1.468547
# ...

# %%
#delete rows with outlier data; put it in a new dataframe
df_clean = df[(df['num_accts'] > 0) & (df['num_accts'] < 10)]

#delete any rows with missing values in the clean dataframe
df_clean = df_clean.dropna() 

df_clean.describe()
# Out:
#            answered         income        female           age           job  \
# count  27581.000000   27581.000000  27581.000000  27581.000000  27581.000000
# mean       0.556796   33268.926072      0.055654     34.492404      1.918821
# std        0.496773   28747.861812      0.229257     11.094958      0.586321
# min        0.000000  -65600.000000      0.000000     19.000000      0.000000
# 25%        0.000000   13640.000000      0.000000     26.000000      2.000000
# 50%        1.000000   23230.000000      0.000000     32.000000      2.000000
# 75%        1.000000   40200.000000      0.000000     40.000000      2.000000
# max        1.000000  159450.000000      1.000000     74.000000      3.000000
#
#        num_dependents          rent       own_res       new_car      chk_acct  \
# count    27581.000000  27581.000000  27581.000000  27581.000000  27581.000000
# mean         1.143867      0.215801      0.682100      0.236685      1.477793
# ...

# %%
df_clean.head(5)
# Out:
#    answered  income  female  age  job  num_dependents  rent  own_res  new_car  \
# 1         0   14780       0   22    2               1     0        1      0.0
# 2         1   37570       0   62    2               1     0        0      1.0
# 3         0   12450       0   33    2               1     0        1      0.0
# 4         0   12400       0   48    1               2     0        0      1.0
# 5         1   14030       0   28    2               1     1        0      1.0
#
#    chk_acct  sav_acct  num_accts  mobile  product
# 1         3         0          3       0        0
# 2         3         0          4       0        4
# 3         1         0          2       0        0
# 4         2         1          4       0        0
# 5         0         0          2       0        4

# %%
df_clean['answered'] = df_clean['answered'].map({1: 'yes', 0: 'no'})
df_clean['answered'] = df_clean['answered'].astype('category')

# %%
df_clean.head(5)
# Out:
#   answered  income  female  age  job  num_dependents  rent  own_res  new_car  \
# 1       no   14780       0   22    2               1     0        1      0.0
# 2      yes   37570       0   62    2               1     0        0      1.0
# 3       no   12450       0   33    2               1     0        1      0.0
# 4       no   12400       0   48    1               2     0        0      1.0
# 5      yes   14030       0   28    2               1     1        0      1.0
#
#    chk_acct  sav_acct  num_accts  mobile  product
# 1         3         0          3       0        0
# 2         3         0          4       0        4
# 3         1         0          2       0        0
# 4         2         1          4       0        0
# 5         0         0          2       0        4

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27581 entries, 1 to 29503
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   answered        27581 non-null  category
#  1   income          27581 non-null  int64
#  2   female          27581 non-null  int64
#  3   age             27581 non-null  int64
#  4   job             27581 non-null  int64
#  5   num_dependents  27581 non-null  int64
#  6   rent            27581 non-null  int64
#  7   own_res         27581 non-null  int64
#  8   new_car         27581 non-null  float64
#  9   chk_acct        27581 non-null  int64
#  10  sav_acct        27581 non-null  int64
#  11  num_accts       27581 non-null  int64
#  12  mobile          27581 non-null  int64
#  13  product         27581 non-null  int64
# dtypes: category(1), float64(1), int64(12)
# memory usage: 3.0 MB

# %% [markdown]
# # Question 1

# %%
# Question 1 Bar Chart

#Figure size
plt.figure(figsize=(9,7))
ax = sns.countplot(x = 'num_accts', hue = 'answered', data = df_clean, palette = "coolwarm_r")
#Add title
plt.title('Yes and No Per Number of Accounts', fontsize=18)
# Out:
# Text(0.5, 1.0, 'Yes and No Per Number of Accounts')

# %% [markdown]
# The bar chart above is for question 1. My comment on what I see in the bar chart is that most people have 2 accounts, then 4 accounts, three accounts, and 1 account. More people answered yes for 2, 3, and 4 accounts while more people answered no for 1 account. In other words, a customer is more likely to answer if they have 2 or more accounts.

# %%
df_clean['mobile'] = df_clean['mobile'].astype('category')

# %%
df_clean['mobile'].unique()
# Out:
# [0, 1]
# Categories (2, int64): [0, 1]

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27581 entries, 1 to 29503
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   answered        27581 non-null  category
#  1   income          27581 non-null  int64
#  2   female          27581 non-null  int64
#  3   age             27581 non-null  int64
#  4   job             27581 non-null  int64
#  5   num_dependents  27581 non-null  int64
#  6   rent            27581 non-null  int64
#  7   own_res         27581 non-null  int64
#  8   new_car         27581 non-null  float64
#  9   chk_acct        27581 non-null  int64
#  10  sav_acct        27581 non-null  int64
#  11  num_accts       27581 non-null  int64
#  12  mobile          27581 non-null  category
#  13  product         27581 non-null  int64
# dtypes: category(2), float64(1), int64(11)
# memory usage: 2.8 MB

# %% [markdown]
# # Question 2

# %%
#Figure size
plt.figure(figsize=(9,7))
ax = sns.countplot(x = 'mobile', hue = 'answered', data = df_clean, palette = "coolwarm_r")
#Add title
plt.title('Yes and No Per Mobile', fontsize=18)
# Out:
# Text(0.5, 1.0, 'Yes and No Per Mobile')

# %% [markdown]
# The bar chart above is for question 2. My comment on what I see in the bar chart is that most people. For both those without and those with a mobile phone, most people seemed to answer. However, the proportion of people who answered with a mobile phone seems to be higher than those that do not answer with a mobile phone In other words, someone is more likely to answer if they have a mobile phone.

# %%
def with_hue(ax, feature, Number_of_categories, hue_categories):
    a = [p.get_height() for p in ax.patches]
    patch = [p for p in ax.patches]
    for i in range(Number_of_categories):
        total = feature.value_counts().values[i]
        for j in range(hue_categories):
            percentage = '{:.1f}%'.format(100 * a[(j*Number_of_categories + i)]/total)
            x = patch[(j*Number_of_categories + i)].get_x() + patch[(j*Number_of_categories + i)].get_width() / 2 - 0.15
            y = patch[(j*Number_of_categories + i)].get_y() + patch[(j*Number_of_categories + i)].get_height() 
            ax.annotate(percentage, (x, y), size = 12)

#Figure size
plt.figure(figsize=(9,7))
ax = sns.countplot(x = 'mobile', hue = 'answered', data = df_clean, palette = "coolwarm_r")
#Add title
plt.title('Yes and No Per Mobile', fontsize=18)

with_hue(ax, df_clean.mobile, 2, 2)
